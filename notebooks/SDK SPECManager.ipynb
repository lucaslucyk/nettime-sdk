# %% [markdown]
# # SPECManager-sdk
# sdk for SPEC Manager

# %% [markdown]
# ### Add src folder to path

# %%
#import sys, os
#sys.path.append(os.path.join(os.getcwd(), '..', 'src'))

# %% [markdown]
# ### Import module

# %%
#import specmanagerdb as smdb
#from importlib import reload

# %% [markdown]
# #### using pypi

# %%
from importlib import reload
from spec_utils import specmanagerdb as smdb

# %% [markdown]
# ### Client settings

# %%
SERVER = 'LUA'
USERNAME = 'sa'
PWD = 'specmanager'
DATABASE = 'LEDESMA'

# %% [markdown]
# ### Create a SPEC Manager Database client

# %%
reload(smdb) # for reaload changes only
client = smdb.Client(
    username=USERNAME,
    pwd=PWD,
    server=SERVER,
    database=DATABASE
)
client.engine
# Out:
# Engine(mssql+pyodbc://sa:***@LUA:1433/LEDESMA?driver=SQL+Server)

# %% [markdown]
# ### Get employees with summary method

# %%
client.get_employees()
# Out:
#    PERS_CODIGO  PERS_TIPO          PERS_PILA PERS_NOMBRE  PERS_PERFIL  \
# 0            2          9            Claudio     Chimale            0
# 1            3          9    RODRIGO NICOLAS      GOMEZ             0
# 2            4          9              PEDRO       SUBIA            0
# 3            5          9  ADRIANA DEL VALLE   ALDERETES            0
# 4            6          9            JOAQUIN     SALINAS            0
#
#    PERS_COMEDOR  PERS_EXTRA  PERS_DNI  PERS_BAJA  PERS_AFBT  ... PERS_PIN  \
# 0             0          55  20327815          0          0  ...     None
# 1             0           0  28884538          0          0  ...     None
# 2             0           0  29223226          0          0  ...     None
# 3             0           0  24164239          0          0  ...     None
# 4             0           0  26475813          0          0  ...     None
#
#   PERS_EMP  PERS_PWD  PERS_PR PERS_EXTN1  PERS_EXTN2 PERS_EXTS1  PERS_EXTS2  \
# ...

# %% [markdown]
# #### Get employees with optional parameters

# %%
client.get_employees(fields=["PERS_CODIGO", "PERS_TIPO", "PERS_DNI", "PERS_BAJA", "PERS_CODIGO"], where="PERS_TIPO != 9")
# Out:
#    PERS_CODIGO  PERS_TIPO  PERS_DNI  PERS_BAJA  PERS_CODIGO
# 0       311175          2  23336030          0       311175
# 1       311176          2      SPEC          0       311176
# 2      4546873          2  04546873          0      4546873
# 3      4702097          2  04702097          0      4702097
# 4      4705042          2  04705042          0      4705042

# %% [markdown]
# ### Get registers from custom table

# %%
client.get_from_table("IMP_PERSONAL")
# Out:
#   SISTEMA ESTADO COD_PERS   TARJETA   INI_VAL   FIN_VAL   APELLIDOS  \
# 0  PROPIO      A        0            20180201  20201231  Giampietro
# 1  PROPIO      A        0  65064505  20180201  20201231        CRUZ
# 2  PROPIO      A        0  24002500  20180201  20201231     BRINGAS
# 3  PROPIO      A        0  66006445  20180201  20201231     CAMACHO
# 4  PROPIO      A        0  24014986  20180201  20201231     LEZCANO
#
#               NOMBRE            DNI COD_CENT  ... F_ALTA_EMPRESA EMPLEO CAL  \
# 0     Guido Ezequiel                       1  ...                     0
# 1  SEBASTIAN RICARDO  20-29274623-8        1  ...                     0
# 2       PABLO HERNAN  20-30925155-6        1  ...                     0
# 3       HERNAN ARIEL  20-27257950-5        1  ...                     0
# 4       PABLO JAVIER  20-28030266-0        1  ...                     0
#
#   CAL_FEST NIF_EMP NOMBRE_EMPLEO FECHA_APLICACION CONTROL_HORARIO  \
# ...

# %% [markdown]
# ### Execute custom query

# %%
client.read_sql_query("SELECT TOP 5 * FROM ORGANIGRAMA")
# Out:
#    GR_APP  GR_ID                                     GR_DESC  GR_GRP  CEN_ID  \
# 0       2      1  IEA SRL - Ingenieria Electronica Argentina       0       0
# 1       9      1                                    SISTEMAS       0       0
# 2       2      2                   MEDINACELI JUANA MILAGROS       0       0
# 3       4      2                                      AZUCAR       0       3
# 4       2      3                             JP Servicios SA       0       0
#
#    GR_PADRE GR_PREFIJO GR_RUTA
# 0       169
# 1         0
# 2       173
# 3        -1
# 4       169

# %% [markdown]
# ### Get Table names

# %%
client.table_names[:5]
# Out:
# ['ACC_ASOC_CALENDARIOS_GLOBALES',
#  'ACC_ASOC_PERFILES',
#  'ACC_CALENDARIOS',
#  'ACC_CALENDARIOS_GLOBALES',
#  'ACC_CAPA_CALABS']

# %% [markdown]
# ### Disconnect

# %%
client.dispose()
